# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file="C:/Users/ProBook/Downloads/used_cars_data.csv"

# %%
df = pd.read_csv(file)
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
df.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#       s.no.                                               name    location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
# s.no.                7253 non-null int64
# name                 7253 non-null object
# location             7253 non-null object
# year                 7253 non-null int64
# kilometers_driven    7253 non-null int64
# fuel_type            7253 non-null object
# transmission         7253 non-null object
# owner_type           7253 non-null object
# mileage              7251 non-null object
# engine               7207 non-null object
# power                7207 non-null object
# seats                7200 non-null float64
# new_price            1006 non-null object
# price                6019 non-null float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
df.isna().sum()
# Out:
# s.no.                   0
# name                    0
# location                0
# year                    0
# kilometers_driven       0
# fuel_type               0
# transmission            0
# owner_type              0
# mileage                 2
# engine                 46
# power                  46
# seats                  53
# new_price            6247
# price                1234
# dtype: int64

# %%
x={"km/kg":" ",
    "kmpl":" " ,
      "CC":" ",
       "bhp":" ",
         "Lakh":" ",
  "null":"0",
  "Cr":" "}

# %%
df=df.replace(x,regex=True)

# %%
df.head()
# Out:
#    s.no.                             name    location  year  \
# 0      0           Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai  eta 1.6 CRDi SX Option        Pune  2015
# 2      2                     Honda Jazz V     Chennai  2011
# 3      3                Maruti Ertiga VDI     Chennai  2012
# 4      4  Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 0              72000       CNG       Manual      First   26.6     998
# 1              41000    Diesel       Manual      First  19.67    1582
# 2              46000    Petrol       Manual      First   18.2    1199
# 3              87000    Diesel       Manual      First  20.77    1248
# 4              40670    Diesel    Automatic     Second   15.2    1968
#
#      power  seats new_price  price
# 0  58.16      5.0       NaN   1.75
# 1  126.2      5.0       NaN  12.50
# 2   88.7      5.0    8.61     4.50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
# s.no.                7253 non-null int64
# name                 7253 non-null object
# location             7253 non-null object
# year                 7253 non-null int64
# kilometers_driven    7253 non-null int64
# fuel_type            7253 non-null object
# transmission         7253 non-null object
# owner_type           7253 non-null object
# mileage              7251 non-null object
# engine               7207 non-null object
# power                7207 non-null object
# seats                7200 non-null float64
# new_price            1006 non-null object
# price                6019 non-null float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
df.columns
# Out:
# Index(['s.no.', 'name', 'location', 'year', 'kilometers_driven', 'fuel_type',
#        'transmission', 'owner_type', 'mileage', 'engine', 'power', 'seats',
#        'new_price', 'price'],
#       dtype='object')

# %%
df['mileage']=pd.to_numeric(df['mileage'])

# %%
df['engine']=pd.to_numeric(df['engine'])

# %%
df['power']=pd.to_numeric(df['power'])

# %%
df.head(77)
# Out:
#     s.no.                             name    location  year  \
# 0       0           Maruti Wagon R LXI CNG      Mumbai  2010
# 1       1  Hyundai  eta 1.6 CRDi SX Option        Pune  2015
# 2       2                     Honda Jazz V     Chennai  2011
# 3       3                Maruti Ertiga VDI     Chennai  2012
# 4       4  Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ..    ...                              ...         ...   ...
# 72     72        Hyundai i10 Sportz 1.2 AT       Kochi  2012
# 73     73          Nissan Terrano XV D Pre       Kochi  2015
# 74     74                 Honda Brio VX AT  Coimbatore  2016
# 75     75   Audi A6 2.0 TDI Design Edition       Delhi  2014
# 76     76         Ford Fiesta 1.4 SXi TDCi      Jaipur  2008
#
#     kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 0               72000       CNG       Manual      First    26.60   998.0
# 1               41000    Diesel       Manual      First    19.67  1582.0
# ...

# %%
df['new_price']=pd.to_numeric(df['new_price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
# s.no.                7253 non-null int64
# name                 7253 non-null object
# location             7253 non-null object
# year                 7253 non-null int64
# kilometers_driven    7253 non-null int64
# fuel_type            7253 non-null object
# transmission         7253 non-null object
# owner_type           7253 non-null object
# mileage              7251 non-null float64
# engine               7207 non-null float64
# power                7207 non-null float64
# seats                7200 non-null float64
# new_price            1006 non-null float64
# price                6019 non-null float64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 793.4+ KB

# %%
df.isna().sum()
# Out:
# s.no.                   0
# name                    0
# location                0
# year                    0
# kilometers_driven       0
# fuel_type               0
# transmission            0
# owner_type              0
# mileage                 2
# engine                 46
# power                  46
# seats                  53
# new_price            6247
# price                1234
# dtype: int64

# %%
n_pri=round(df['new_price'].mean(),2)
n_pri
# Out:
# 19.89

# %%
df['new_price']=df['new_price'].fillna(n_pri)

# %%
df.isna().sum()
# Out:
# s.no.                   0
# name                    0
# location                0
# year                    0
# kilometers_driven       0
# fuel_type               0
# transmission            0
# owner_type              0
# mileage                 2
# engine                 46
# power                  46
# seats                  53
# new_price               0
# price                1234
# dtype: int64

# %%
pri=round(df['price'].mean(),2)
pri
# Out:
# 9.48

# %%
df['price']=df['price'].fillna(pri)

# %%
df.isna().sum()
# Out:
# s.no.                 0
# name                  0
# location              0
# year                  0
# kilometers_driven     0
# fuel_type             0
# transmission          0
# owner_type            0
# mileage               2
# engine               46
# power                46
# seats                53
# new_price             0
# price                 0
# dtype: int64

# %%
mil=round(df['mileage'].mean(),2)
mil
df['mileage']=df['mileage'].fillna(mil)

# %%
eng=round(df['engine'].mean(),2)
eng
df['engine']=df['engine'].fillna(eng)

# %%
po=round(df['power'].mean(),2)
po
df['power']=df['power'].fillna(po)

# %%
sit=round(df['seats'].mean(),2)
sit
df['seats']=df['seats'].fillna(sit)

# %%
df.isna().sum()
# Out:
# s.no.                0
# name                 0
# location             0
# year                 0
# kilometers_driven    0
# fuel_type            0
# transmission         0
# owner_type           0
# mileage              0
# engine               0
# power                0
# seats                0
# new_price            0
# price                0
# dtype: int64

# %%
df.head()
# Out:
#    s.no.                             name    location  year  \
# 0      0           Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai  eta 1.6 CRDi SX Option        Pune  2015
# 2      2                     Honda Jazz V     Chennai  2011
# 3      3                Maruti Ertiga VDI     Chennai  2012
# 4      4  Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
#
#     power  seats  new_price  price
# 0   58.16    5.0      19.89   1.75
# 1  126.20    5.0      19.89  12.50
# 2   88.70    5.0       8.61   4.50
# ...

# %%
df.describe()
# Out:
#              s.no.         year  kilometers_driven      mileage       engine  \
# count  7253.000000  7253.000000       7.253000e+03  7253.000000  7253.000000
# mean   3626.000000  2013.365366       5.869906e+04    18.141580  1616.573448
# std    2093.905084     3.254421       8.442772e+04     4.561567   593.394164
# min       0.000000  1996.000000       1.710000e+02     0.000000    72.000000
# 25%    1813.000000  2011.000000       3.400000e+04    15.170000  1198.000000
# 50%    3626.000000  2014.000000       5.341600e+04    18.160000  1493.000000
# 75%    5439.000000  2016.000000       7.300000e+04    21.100000  1968.000000
# max    7252.000000  2019.000000       6.500000e+06    33.540000  5998.000000
#
#              power        seats    new_price        price
# count  7253.000000  7253.000000  7253.000000  7253.000000
# mean    110.746820     5.279724    19.890600     9.479559
# std      54.905856     0.808688     7.376072    10.191695
# ...

# %%
#(1a) number of cars using petrol and diesel in Mumbai
cars_mumbai=df[(df.location=="Mumbai")]
cars_mumbai
# Out:
#       s.no.                                  name location  year  \
# 0         0                Maruti Wagon R LXI CNG   Mumbai  2010
# 7         7      Toyota Innova  ysta 2.8 GX AT 8S   Mumbai  2016
# 22       22  Audi A6 2011-2015 35 TFSI Technology   Mumbai  2015
# 25       25          Honda City Corporate Edition   Mumbai  2012
# 29       29   Toyota Innova 2.5 V Diesel 7-seater   Mumbai  2007
# ...     ...                                   ...      ...   ...
# 7185   7185           Hyundai i20 Asta Option 1.2   Mumbai  2015
# 7218   7218     Maruti Vitara Brezza ZDi Plus AMT   Mumbai  2018
# 7229   7229   Volkswagen Vento Petrol Highline AT   Mumbai  2011
# 7232   7232                Jeep Compass 1.4 Sport   Mumbai  2018
# 7249   7249                Volkswagen Polo GT TSI   Mumbai  2015
#
#       kilometers_driven fuel_type transmission      owner_type  mileage  \
# 0                 72000       CNG       Manual           First    26.60
# ...

# %%
y = cars_mumbai[(cars_mumbai.fuel_type=="Diesel")|(cars_mumbai.fuel_type=="Petrol")]
y
# Out:
#       s.no.                                  name location  year  \
# 7         7      Toyota Innova  ysta 2.8 GX AT 8S   Mumbai  2016
# 22       22  Audi A6 2011-2015 35 TFSI Technology   Mumbai  2015
# 25       25          Honda City Corporate Edition   Mumbai  2012
# 29       29   Toyota Innova 2.5 V Diesel 7-seater   Mumbai  2007
# 45       45             Toyota Corolla Altis G AT   Mumbai  2016
# ...     ...                                   ...      ...   ...
# 7185   7185           Hyundai i20 Asta Option 1.2   Mumbai  2015
# 7218   7218     Maruti Vitara Brezza ZDi Plus AMT   Mumbai  2018
# 7229   7229   Volkswagen Vento Petrol Highline AT   Mumbai  2011
# 7232   7232                Jeep Compass 1.4 Sport   Mumbai  2018
# 7249   7249                Volkswagen Polo GT TSI   Mumbai  2015
#
#       kilometers_driven fuel_type transmission      owner_type  mileage  \
# 7                 36000    Diesel    Automatic           First    11.36
# ...

# %%
dp = np.array(y["fuel_type"])

# %%
len(dp)
# Out:
# 929

# %%
#1b the cheapest cars satisfying (a)
cm=y.sort_values(by=['new_price'],ascending=True).head()
cm
# Out:
#       s.no.                                     name location  year  \
# 1336   1336        Audi Q7 45 TDI Quattro Technology   Mumbai  2016
# 2178   2178  Land Rover Discovery HSE Luxury 3.0 TD6   Mumbai  2017
# 148     148                           Audi RS5 Coupe   Mumbai  2013
# 4061   4061                           Audi RS5 Coupe   Mumbai  2013
# 1872   1872            Maruti Eeco 7 Seater Standard   Mumbai  2014
#
#       kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 1336              20002    Diesel    Automatic      First    14.75  2967.0
# 2178              35000    Diesel    Automatic      First    18.00  2993.0
# 148               23000    Petrol    Automatic      First    11.05  2894.0
# 4061              23312    Petrol    Automatic      First    11.05  2894.0
# 1872              34669    Petrol       Manual      First    15.10  1196.0
#
#       power  seats  new_price  price
# 1336  245.0    7.0       1.04   67.0
# ...

# %%
#How many automatic cars are there in Chennai and their new prices
chen= df[(df.location=='Chennai')]
chen
# Out:
#       s.no.                                   name location  year  \
# 2         2                           Honda Jazz V  Chennai  2011
# 3         3                      Maruti Ertiga VDI  Chennai  2012
# 9         9         Tata Indica Vista Quadrajet LS  Chennai  2012
# 39       39  Volkswagen Polo Diesel Trendline 1.2L  Chennai  2013
# 54       54               Hyundai Grand i10 Sportz  Chennai  2015
# ...     ...                                    ...      ...   ...
# 7195   7195                    Hyundai i10 Era 1.1  Chennai  2008
# 7222   7222                  Maruti Celerio VXI AT  Chennai  2015
# 7224   7224                     Datsun GO T Petrol  Chennai  2016
# 7227   7227  Mahindra Renault Logan 1.5 DLE Diesel  Chennai  2007
# 7243   7243         Renault Duster 85PS Diesel RxL  Chennai  2015
#
#       kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 2                 46000    Petrol       Manual      First    18.20  1199.0
# ...

# %%
chen_auto=chen[(chen.transmission=='Automatic')]
chen_no=len(np.array(chen_auto["fuel_type"]))
chen_no
# Out:
# 136

# %%
chen_auto[['name','transmission','new_price']]
# Out:
#                                                 name transmission  new_price
# 166   Volkswagen Vento 1.5 Highline Plus AT 16 Alloy    Automatic      19.89
# 336                                Toyota Corolla H4    Automatic      19.89
# 374                  Mercedes-Benz GLA Class 200 CDI    Automatic      19.89
# 396                          BMW 3 Series 320d Sedan    Automatic      19.89
# 398                        Audi A3 35 TDI Attraction    Automatic      19.89
# ...                                              ...          ...        ...
# 6950                    Hyundai Verna 1.6 VTVT EX AT    Automatic      19.89
# 7002            Audi A6 2011-2015 2.0 TDI Technology    Automatic      19.89
# 7062                  Mercedes-Benz A Class A180 CDI    Automatic      19.89
# 7148                       Hyundai i20 1.4 Asta (AT)    Automatic      19.89
# 7222                           Maruti Celerio VXI AT    Automatic      19.89
#
# [136 rows x 3 columns]

# %%
y.head()
# Out:
#     s.no.                                  name location  year  \
# 7       7      Toyota Innova  ysta 2.8 GX AT 8S   Mumbai  2016
# 22     22  Audi A6 2011-2015 35 TFSI Technology   Mumbai  2015
# 25     25          Honda City Corporate Edition   Mumbai  2012
# 29     29   Toyota Innova 2.5 V Diesel 7-seater   Mumbai  2007
# 45     45             Toyota Corolla Altis G AT   Mumbai  2016
#
#     kilometers_driven fuel_type transmission      owner_type  mileage  engine  \
# 7               36000    Diesel    Automatic           First    11.36  2755.0
# 22              55985    Petrol    Automatic           First    13.53  1984.0
# 25              51920    Petrol       Manual           First    16.80  1497.0
# 29             262000    Diesel       Manual  Fourth & Above    12.80  2494.0
# 45              52001    Petrol    Automatic           First    14.28  1798.0
#
#      power  seats  new_price  price
# 7   171.50    8.0      21.00  17.50
# 22  177.01    5.0      19.89  23.50
# ...

# %%
# which cars have mileage greater than mean mileage
mean_mileage=round(df['mileage'].mean(),2)
mean_mileage
# Out:
# 18.14

# %%
greater_than_mean=df[(df.mileage>18.14)]
greater_than_mean.head()
# Out:
#    s.no.                             name   location  year  kilometers_driven  \
# 0      0           Maruti Wagon R LXI CNG     Mumbai  2010              72000
# 1      1  Hyundai  eta 1.6 CRDi SX Option       Pune  2015              41000
# 2      2                     Honda Jazz V    Chennai  2011              46000
# 3      3                Maruti Ertiga VDI    Chennai  2012              87000
# 5      5  Hyundai EON LPG Era Plus Option  Hyderabad  2012              75000
#
#   fuel_type transmission owner_type  mileage  engine   power  seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 5       LPG       Manual      First    21.10   814.0   55.20    5.0
#
#    new_price  price
# 0      19.89   1.75
# 1      19.89  12.50
# 2       8.61   4.50
# ...

# %%
greater_than=greater_than_mean.sort_values(by=['mileage'],ascending=False)
greater_than.head()
# Out:
#       s.no.                    name location  year  kilometers_driven  \
# 1332   1332  Maruti Wagon R CNG LXI     Pune  2013              79494
# 4141   4141  Maruti Wagon R CNG LXI   Mumbai  2014              47200
# 3129   3129  Maruti Wagon R CNG LXI    Delhi  2014              74663
# 2059   2059  Maruti Wagon R CNG LXI   Mumbai  2013              54000
# 2371   2371  Maruti Wagon R CNG LXI     Pune  2014              29202
#
#      fuel_type transmission owner_type  mileage  engine  power  seats  \
# 1332       CNG       Manual      First    33.54   998.0  67.04    5.0
# 4141       CNG       Manual      First    33.54   998.0  67.04    5.0
# 3129       CNG       Manual      First    33.54   998.0  67.04    5.0
# 2059       CNG       Manual      First    33.54   998.0  67.04    5.0
# 2371       CNG       Manual      First    33.54   998.0  67.04    5.0
#
#       new_price  price
# 1332       5.54   2.96
# 4141       5.58   2.85
# 3129       5.35   3.25
# 2059       5.58   3.05
# ...

# %%
mm=greater_than[['name','mileage']].head(10)
mm
# Out:
#                                    name  mileage
# 1332             Maruti Wagon R CNG LXI    33.54
# 4141             Maruti Wagon R CNG LXI    33.54
# 3129             Maruti Wagon R CNG LXI    33.54
# 2059             Maruti Wagon R CNG LXI    33.54
# 2371             Maruti Wagon R CNG LXI    33.54
# 3869  Maruti Alto 800 2016-2019 CNG LXI    33.44
# 3553  Maruti Alto 800 2016-2019 CNG LXI    33.44
# 1269  Maruti Alto 800 2016-2019 CNG LXI    33.44
# 4769  Maruti Alto 800 2016-2019 CNG LXI    33.44
# 5935            Maruti Alto K10 LXI CNG    32.26

# %%
mm.plot(y='mileage',x='name',kind='bar')

# %%
#which cars have speedometer driven than the mean 
mean_speed=round(df['kilometers_driven'].mean(),2)
mean_speed
# Out:
# 58699.06

# %%
greater_mean_speed=df[(df.kilometers_driven>58699.06)]
greater_mean_speed.head()
# Out:
#    s.no.                                 name   location  year  \
# 0      0               Maruti Wagon R LXI CNG     Mumbai  2010
# 3      3                    Maruti Ertiga VDI    Chennai  2012
# 5      5      Hyundai EON LPG Era Plus Option  Hyderabad  2012
# 6      6               Nissan Micra Diesel XV     Jaipur  2013
# 8      8  Volkswagen Vento Diesel Comfortline       Pune  2013
#
#    kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 5              75000       LPG       Manual      First    21.10   814.0
# 6              86999    Diesel       Manual      First    23.08  1461.0
# 8              64430    Diesel       Manual      First    20.54  1598.0
#
#     power  seats  new_price  price
# 0   58.16    5.0      19.89   1.75
# 3   88.76    7.0      19.89   6.00
# 5   55.20    5.0      19.89   2.35
# ...

# %%
#which cars have engine greater than modal engine power
mode=round(df['power'].mode(),2)
mode
# Out:
# 0    74.0
# dtype: float64

# %%
greater_mode=df[(df.power>74)]
greater_mode.head()
# Out:
#    s.no.                              name    location  year  \
# 1      1   Hyundai  eta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 7      7  Toyota Innova  ysta 2.8 GX AT 8S      Mumbai  2016
#
#    kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
# 7              36000    Diesel    Automatic      First    11.36  2755.0
#
#     power  seats  new_price  price
# 1  126.20    5.0      19.89  12.50
# 2   88.70    5.0       8.61   4.50
# 3   88.76    7.0      19.89   6.00
# ...

# %%
#Machine Learning

# %%
var = df.copy()
var.head()
# Out:
#    s.no.                             name    location  year  \
# 0      0           Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai  eta 1.6 CRDi SX Option        Pune  2015
# 2      2                     Honda Jazz V     Chennai  2011
# 3      3                Maruti Ertiga VDI     Chennai  2012
# 4      4  Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
#
#     power  seats  new_price  price
# 0   58.16    5.0      19.89   1.75
# 1  126.20    5.0      19.89  12.50
# 2   88.70    5.0       8.61   4.50
# ...

# %%
var.columns
# Out:
# Index(['s.no.', 'name', 'location', 'year', 'kilometers_driven', 'fuel_type',
#        'transmission', 'owner_type', 'mileage', 'engine', 'power', 'seats',
#        'new_price', 'price'],
#       dtype='object')

# %%
y=var["price"]
y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 7248     9.48
# 7249     9.48
# 7250     9.48
# 7251     9.48
# 7252     9.48
# Name: price, Length: 7253, dtype: float64

# %%
var['location'].unique()
# Out:
# array(['Mumbai', 'Pune', 'Chennai', 'Coimbatore', 'Hyderabad', 'Jaipur',
#        'Kochi', 'Kolkata', 'Delhi', 'Bangalore', 'Ahmedabad'],
#       dtype=object)

# %%
def location_func (var):
    if var["location"]=="Pune"or var["location"]=="Mumbai":
        return "west"
    elif var["location"]=="Chennai"or var["location"]=="Kolkata" or ["location"]=="Jaipur":
        return "East"
    elif var["location"]=="Delhi"or var["location"]=="Jaipur":
        return "north"
    elif var["location"]=="Coimbatore" or var["location"]=='Bangalore':
        return "south"
var["zones"]= var.apply(location_func,axis=1)

# %%
var.head(1)
# Out:
#    s.no.                    name location  year  kilometers_driven fuel_type  \
# 0      0  Maruti Wagon R LXI CNG   Mumbai  2010              72000       CNG
#
#   transmission owner_type  mileage  engine  power  seats  new_price  price  \
# 0       Manual      First     26.6   998.0  58.16    5.0      19.89   1.75
#
#   zones
# 0  west

# %%
p=var.columns

# %%
p
# Out:
# Index(['s.no.', 'name', 'location', 'year', 'kilometers_driven', 'fuel_type',
#        'transmission', 'owner_type', 'mileage', 'engine', 'power', 'seats',
#        'new_price', 'price', 'zones'],
#       dtype='object')

# %%
len(p)
# Out:
# 15

# %%
x_columns=p[1:12]
x_columns
# Out:
# Index(['name', 'location', 'year', 'kilometers_driven', 'fuel_type',
#        'transmission', 'owner_type', 'mileage', 'engine', 'power', 'seats'],
#       dtype='object')

# %%
#to make it a list
x_col=[]
for i in x_columns:
    x_col.append(i)
print(x_col)
# Out:
# ['name', 'location', 'year', 'kilometers_driven', 'fuel_type', 'transmission', 'owner_type', 'mileage', 'engine', 'power', 'seats']

# %%
x_columns=var[x_col]
x_columns
# Out:
#                                                    name    location  year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                       Hyundai  eta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# ...

# %%
x_columns.head()
# Out:
#                               name    location  year  kilometers_driven  \
# 0           Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai  eta 1.6 CRDi SX Option        Pune  2015              41000
# 2                     Honda Jazz V     Chennai  2011              46000
# 3                Maruti Ertiga VDI     Chennai  2012              87000
# 4  Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   fuel_type transmission owner_type  mileage  engine   power  seats
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0

# %%
x_columns['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
y = var["price"]

# %%
y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 7248     9.48
# 7249     9.48
# 7250     9.48
# 7251     9.48
# 7252     9.48
# Name: price, Length: 7253, dtype: float64

# %%
#machine learning does not recognize string values,ue encoding to convert the tables with string.

# %%
x_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 11 columns):
# name                 7253 non-null object
# location             7253 non-null object
# year                 7253 non-null int64
# kilometers_driven    7253 non-null int64
# fuel_type            7253 non-null object
# transmission         7253 non-null object
# owner_type           7253 non-null object
# mileage              7253 non-null float64
# engine               7253 non-null float64
# power                7253 non-null float64
# seats                7253 non-null float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 623.4+ KB

# %%
h=x_columns.select_dtypes(include= np.object)
list_h = h.columns.to_list()
list_h
# Out:
# ['name', 'location', 'fuel_type', 'transmission', 'owner_type']

# %%
p=x_columns.select_dtypes(include=np.number)
list_p=p.columns.to_list()
list_p
# Out:
# ['year', 'kilometers_driven', 'mileage', 'engine', 'power', 'seats']

# %%
non_numeric=x_columns[list_h]

# %%
non_numeric.head()
# Out:
#                               name    location fuel_type transmission  \
# 0           Maruti Wagon R LXI CNG      Mumbai       CNG       Manual
# 1  Hyundai  eta 1.6 CRDi SX Option        Pune    Diesel       Manual
# 2                     Honda Jazz V     Chennai    Petrol       Manual
# 3                Maruti Ertiga VDI     Chennai    Diesel       Manual
# 4  Audi A4 New 2.0 TDI Multitronic  Coimbatore    Diesel    Automatic
#
#   owner_type
# 0      First
# 1      First
# 2      First
# 3      First
# 4     Second

# %%
numeric_val=x_columns[list_p]
numeric_val
# Out:
#       year  kilometers_driven  mileage  engine   power  seats
# 0     2010              72000    26.60   998.0   58.16    5.0
# 1     2015              41000    19.67  1582.0  126.20    5.0
# 2     2011              46000    18.20  1199.0   88.70    5.0
# 3     2012              87000    20.77  1248.0   88.76    7.0
# 4     2013              40670    15.20  1968.0  140.80    5.0
# ...    ...                ...      ...     ...     ...    ...
# 7248  2011              89411    20.54  1598.0  103.60    5.0
# 7249  2015              59000    17.21  1197.0  103.60    5.0
# 7250  2012              28000    23.08  1461.0   63.10    5.0
# 7251  2013              52262    17.20  1197.0  103.60    5.0
# 7252  2014              72443    10.00  2148.0  170.00    5.0
#
# [7253 rows x 6 columns]

# %%
year_df=numeric_val[["year"]]
year_df
# Out:
#       year
# 0     2010
# 1     2015
# 2     2011
# 3     2012
# 4     2013
# ...    ...
# 7248  2011
# 7249  2015
# 7250  2012
# 7251  2013
# 7252  2014
#
# [7253 rows x 1 columns]

# %%
numeric=numeric_val.drop(['year'],axis=1)

# %%
numeric
# Out:
#       kilometers_driven  mileage  engine   power  seats
# 0                 72000    26.60   998.0   58.16    5.0
# 1                 41000    19.67  1582.0  126.20    5.0
# 2                 46000    18.20  1199.0   88.70    5.0
# 3                 87000    20.77  1248.0   88.76    7.0
# 4                 40670    15.20  1968.0  140.80    5.0
# ...                 ...      ...     ...     ...    ...
# 7248              89411    20.54  1598.0  103.60    5.0
# 7249              59000    17.21  1197.0  103.60    5.0
# 7250              28000    23.08  1461.0   63.10    5.0
# 7251              52262    17.20  1197.0  103.60    5.0
# 7252              72443    10.00  2148.0  170.00    5.0
#
# [7253 rows x 5 columns]

# %%
# df_numeric.to_csv("numeric_values.csv", index=False)
# numeric_df=pd.read_csv("numeric_values.csv")
# numeric_df.head()

# %%
# df_numeric=var._get_numeric_data()
# # df_numeric
# numeric_val = df_numeric.drop(['s.no.', 'year'])
# numeric_val

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
pn=non_numeric.columns

# %%
for i in pn:
    non_numeric[i]=label_encoder.fit_transform(non_numeric[i])
# Out:
# C:\Users\ProBook\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
non_numeric
# Out:
#       name  location  fuel_type  transmission  owner_type
# 0     1310         9          0             1           0
# 1      551        10          1             1           0
# 2      529         2          4             1           0
# 3     1160         2          1             1           0
# 4       23         3          1             0           2
# ...    ...       ...        ...           ...         ...
# 7248  2013         5          1             1           0
# 7249  1988         9          4             0           0
# 7250  1499         8          1             1           0
# 7251  1988        10          4             0           3
# 7252  1366         7          1             0           0
#
# [7253 rows x 5 columns]

# %%
non_numeric['transmission'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
ml_data=pd.concat([numeric,non_numeric],axis=1)

# %%
ml_data
# Out:
#       kilometers_driven  mileage  engine   power  seats  name  location  \
# 0                 72000    26.60   998.0   58.16    5.0  1310         9
# 1                 41000    19.67  1582.0  126.20    5.0   551        10
# 2                 46000    18.20  1199.0   88.70    5.0   529         2
# 3                 87000    20.77  1248.0   88.76    7.0  1160         2
# 4                 40670    15.20  1968.0  140.80    5.0    23         3
# ...                 ...      ...     ...     ...    ...   ...       ...
# 7248              89411    20.54  1598.0  103.60    5.0  2013         5
# 7249              59000    17.21  1197.0  103.60    5.0  1988         9
# 7250              28000    23.08  1461.0   63.10    5.0  1499         8
# 7251              52262    17.20  1197.0  103.60    5.0  1988        10
# 7252              72443    10.00  2148.0  170.00    5.0  1366         7
#
#       fuel_type  transmission  owner_type
# 0             0             1           0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
#for outliers to get data that falls within the range
scaler=MinMaxScaler()
convert_val=pd.DataFrame(scaler.fit_transform(numeric),columns=numeric.columns,index=numeric.index)

# %%
convert_val.head()
# Out:
#    kilometers_driven   mileage    engine     power  seats
# 0           0.011051  0.793083  0.156261  0.094416    0.5
# 1           0.006282  0.586464  0.254809  0.204870    0.5
# 2           0.007051  0.542636  0.190179  0.143994    0.5
# 3           0.013359  0.619261  0.198448  0.144091    0.7
# 4           0.006231  0.453190  0.319946  0.228571    0.5

# %%
#add year
year_df=var[["year"]]
year_df
# Out:
#       year
# 0     2010
# 1     2015
# 2     2011
# 3     2012
# 4     2013
# ...    ...
# 7248  2011
# 7249  2015
# 7250  2012
# 7251  2013
# 7252  2014
#
# [7253 rows x 1 columns]

# %%
concat_val=pd.concat([numeric_val,non_numeric],axis=1)

# %%
concat_val
# Out:
#       year  kilometers_driven  mileage  engine   power  seats  name  location  \
# 0     2010              72000    26.60   998.0   58.16    5.0  1310         9
# 1     2015              41000    19.67  1582.0  126.20    5.0   551        10
# 2     2011              46000    18.20  1199.0   88.70    5.0   529         2
# 3     2012              87000    20.77  1248.0   88.76    7.0  1160         2
# 4     2013              40670    15.20  1968.0  140.80    5.0    23         3
# ...    ...                ...      ...     ...     ...    ...   ...       ...
# 7248  2011              89411    20.54  1598.0  103.60    5.0  2013         5
# 7249  2015              59000    17.21  1197.0  103.60    5.0  1988         9
# 7250  2012              28000    23.08  1461.0   63.10    5.0  1499         8
# 7251  2013              52262    17.20  1197.0  103.60    5.0  1988        10
# 7252  2014              72443    10.00  2148.0  170.00    5.0  1366         7
#
# ...

# %%
concat_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 11 columns):
# year                 7253 non-null int64
# kilometers_driven    7253 non-null int64
# mileage              7253 non-null float64
# engine               7253 non-null float64
# power                7253 non-null float64
# seats                7253 non-null float64
# name                 7253 non-null int32
# location             7253 non-null int32
# fuel_type            7253 non-null int32
# transmission         7253 non-null int32
# owner_type           7253 non-null int32
# dtypes: float64(4), int32(5), int64(2)
# memory usage: 481.8 KB

# %%
#for every machine learning model,split into 30,70
#70% to train,30% to test
#y = price

# %%
X_train,X_test,y_train,y_test=train_test_split(concat_val,y,test_size=0.29,random_state=4)

# %%
X_train.head()
# Out:
#       year  kilometers_driven  mileage  engine   power  seats  name  location  \
# 4058  2016              77000    12.63  2179.0  147.50    5.0   877         4
# 1141  2017              30090    19.60  1461.0  108.45    5.0  1560         3
# 2661  2008              41000    10.40  2773.0  201.00    5.0    26         0
# 1756  2008             150000    28.40  1248.0   74.00    5.0  1230        10
# 2902  2015              25470    20.73  1373.0   91.10    5.0  1136         8
#
#       fuel_type  transmission  owner_type
# 4058          1             0           0
# 1141          1             0           0
# 2661          4             0           2
# 1756          1             1           2
# 2902          4             1           0

# %%
X_train.shape
# Out:
# (5149, 11)

# %%
X_test.shape
# Out:
# (2104, 11)

# %%
y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 7248     9.48
# 7249     9.48
# 7250     9.48
# 7251     9.48
# 7252     9.48
# Name: price, Length: 7253, dtype: float64

# %%
#ASSIGNMENT
#test model accuracy
from sklearn.linear_model import LinearRegression
starex=LinearRegression()
    #read about svm,supervised learning algorithms,unsupervised learning algorithmns
    #pick top 5 of each of them and write short noted on them
    #algorithmns built on regression or classification

# %%
sta_fit=starex.fit(X_train,y_train)
sta_fit
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn import metrics

rsq = starex.score(X_test,y_test)

rsq
# Out:
# 0.5328470400535059

# %%
from sklearn import metrics

rsq = starex.score(X_train,y_train)

rsq
# Out:
# 0.5942936892390253

# %%
X_train.columns

# %%
pred=[]
for i in range(0,len(X_train.columns)):
    value=float(input("Enter new Value:"))
    pred.append(value)
print(pred)

# %%
pred_price=sta_fit.predict([pred])
print(pred_price)
